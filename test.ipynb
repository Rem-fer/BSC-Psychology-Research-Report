# %%
import pandas as pd
import os
import plotly.express as px
from scipy import stats
import statsmodels.formula.api as smf
import json

# %%
def get_study_summary():
    with open("content_for_llm/study_summary.txt", "r") as f:
        summary = f.read()
    return summary

# %%
def get_study_resulst():
    with open ("content_for_llm/resulsts.json", "r") as f:
        resulst = json.load(f)
    return resulst
print(get_study_resulst())
# Out:
# {'multiple_regression': {'model': 'z_pickups ~ maas_score + inhibition_score', 'r_squared': 0.124, 'adj_r_squared': 0.061, 'f_statistic': 1.98, 'df': [2, 26], 'p_value': 0.392, 'durbin_watson': 1.56, 'predictors': {'maas_score': {'beta': -0.053, 't': -0.258, 'p_value': 0.798, 'significant': False}, 'inhibition_score': {'beta': -0.239, 't': -1.165, 'p_value': 0.255, 'significant': False}}}, 'simple_regression': {'model': 'inhibition_score ~ maas_score', 'r_squared': 0.147, 'adj_r_squared': 0.115, 'f_statistic': 4.652, 'df': [1, 27], 'p_value': 0.04, 'durbin_watson': 1.182, 'predictors': {'maas_score': {'beta': 0.383, 't': 2.157, 'p_value': 0.04, 'significant': True, 'unit_change': '1 unit increase in MAAS = 7.77 unit increase in inhibition'}}}, 'descriptive_stats': {'maas_score': {'mean': 3.91, 'sd': 0.69, 'skewness': 0.4, 'kurtosis': 1.09, 'shapiro_w': 0.9574, 'shapiro_p': 0.2487, 'normal': True}, 'inhibition_score': {'mean': 48.26, 'sd': 14.46, 'skewness': 0.06, 'kurtosis': -0.6, 's
# ...
